# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\user\onedrive\documents\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\user\onedrive\documents\lib\site-packages (from opencv-python) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread('avengers.jpg')

image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(image_rgb)
plt.title('Original Image (RGB)')

image_gray = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2GRAY)

plt.subplot(1, 2, 2)
plt.imshow(image_gray, cmap='gray')
plt.title('Grayscale Image')
plt.show()
